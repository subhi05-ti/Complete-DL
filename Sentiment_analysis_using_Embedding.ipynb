# %%
doc = {
    'jai ho',
    'heetega bhai jeetega india jeetega',
    'bharat mata ki jai ho',
    'modi ji jindabaad',
    'inqulab',
    'jindabaad',
    'hurryy hurryy',
    'can i help you',
    'ohh that you',
}

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer(oov_token = 'nothing')
tokenizer.fit_on_texts(doc)

# %%
tokenizer.word_index
# Out:
# {'nothing': 1,
#  'jai': 2,
#  'ho': 3,
#  'jindabaad': 4,
#  'hurryy': 5,
#  'jeetega': 6,
#  'you': 7,
#  'bharat': 8,
#  'mata': 9,
#  'ki': 10,
#  'inqulab': 11,
#  'modi': 12,
#  'ji': 13,
#  'heetega': 14,
#  'bhai': 15,
#  'india': 16,
#  'can': 17,
#  'i': 18,
#  'help': 19,
#  'ohh': 20,
#  'that': 21}

# %%
len(tokenizer.word_index)
# Out:
# 21

# %%
tokenizer.document_count
# Out:
# 9

# %%
sequences = tokenizer.texts_to_sequences(doc)
sequences
# Out:
# [[8, 9, 10, 2, 3],
#  [2, 3],
#  [4],
#  [5, 5],
#  [11],
#  [12, 13, 4],
#  [14, 15, 6, 16, 6],
#  [17, 18, 19, 7],
#  [20, 21, 7]]

# %%
# adding padding
from keras.utils import pad_sequences
sequences = pad_sequences(sequences, padding = 'post')
sequences
# Out:
# array([[ 8,  9, 10,  2,  3],
#        [ 2,  3,  0,  0,  0],
#        [ 4,  0,  0,  0,  0],
#        [ 5,  5,  0,  0,  0],
#        [11,  0,  0,  0,  0],
#        [12, 13,  4,  0,  0],
#        [14, 15,  6, 16,  6],
#        [17, 18, 19,  7,  0],
#        [20, 21,  7,  0,  0]], dtype=int32)

# %%
# mmodel
from keras.models import Sequential
from keras.layers import Dense, Embedding, Flatten

model = Sequential()
model.add(Embedding(len(tokenizer.word_index) + 1, output_dim=2, input_shape=(5,)))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_2 (Embedding)         │ (None, 5, 2)           │            44 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44 (176.00 B)
#  Trainable params: 44 (176.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam','accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# [[[-0.01248783  0.0132846 ]
#   [-0.00295753 -0.04387592]
#   [-0.03322852 -0.03512001]
#   [ 0.03481073  0.01960087]
#   [-0.0043924  -0.04227401]]
#
#  [[ 0.03481073  0.01960087]
#   [-0.0043924  -0.04227401]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]]
#
#  [[-0.03543557  0.01161271]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]]
#
#  [[ 0.00036118 -0.02611793]
#   [ 0.00036118 -0.02611793]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]]
#
#  [[-0.04310092 -0.03738533]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]]
#
#  [[ 0.03650009 -0.04496048]
#   [ 0.01872173  0.0083732 ]
#   [-0.03543557  0.01161271]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]]
#
#  [[ 0.03244082 -0.03926229]
#   [ 0.04206976 -0.02464702]
#   [ 0.02474621  0.03885828]
#   [ 0.00639901 -0.04828427]
#   [ 0.02474621  0.03885828]]
#
#  [[-0.03905717  0.00104029]
#   [ 0.04750529 -0.04107368]
#   [-0.01086042  0.04510465]
#   [-0.01203766 -0.02358492]
#   [ 0.03477991 -0.00102577]]
#
#  [[-0.02208053  0.02625996]
#   [-0.01630371  0.02222196]
#   [-0.01203766 -0.02358492]
#   [ 0.03477991 -0.00102577]
#   [ 0.03477991 -0.00102577]]]

# %% [markdown]
# **IMDB**

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras import Sequential
from keras.layers import Dense,SimpleRNN,Embedding,Flatten

# %%
from keras.datasets import imdb

# %%
(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
x_train = pad_sequences(x_train,padding='post',maxlen=50)
x_test = pad_sequences(x_test,padding='post',maxlen=50)

# %%
x_train.shape
# Out:
# (25000, 50)

# %%
model = Sequential()
model.add(Embedding(10000,2, input_shape=(50,)))
model.add(SimpleRNN(32,return_sequences=False))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 50, 2)          │        20,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, 32)             │         1,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 21,153 (82.63 KB)
#  Trainable params: 21,153 (82.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer='adam',
    loss = 'binary_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(x_train,y_train,epochs=5,validation_data=(x_test,y_test))
# Out:
# Epoch 1/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 13s 13ms/step - accuracy: 0.5263 - loss: 0.6837 - val_accuracy: 0.7715 - val_loss: 0.4796
# Epoch 2/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8107 - loss: 0.4223 - val_accuracy: 0.8124 - val_loss: 0.4152
# Epoch 3/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.8721 - loss: 0.3126 - val_accuracy: 0.7998 - val_loss: 0.4461
# Epoch 4/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9009 - loss: 0.2563 - val_accuracy: 0.8044 - val_loss: 0.4543
# Epoch 5/5
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 6s 8ms/step - accuracy: 0.9196 - loss: 0.2187 - val_accuracy: 0.7957 - val_loss: 0.5216
