# %%
# importing the dependencies
from keras.models import Sequential
from keras.layers import Dense,SimpleRNN

# %%
model = Sequential()
model.add(SimpleRNN(3,input_shape=(4,5)))
model.add(Dense(1,activation='sigmoid'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.get_weights()[0].shape)
print(model.get_weights())
# Out:
# (5, 3)
# [array([[-0.5798466 ,  0.2800476 , -0.1869387 ],
#        [-0.52651536,  0.10413212, -0.68871695],
#        [-0.11929303, -0.01671261,  0.6724258 ],
#        [ 0.8392381 ,  0.8242007 , -0.09130085],
#        [-0.19911152,  0.22156435,  0.5324628 ]], dtype=float32), array([[-0.11843264,  0.6555819 , -0.7457789 ],
#        [-0.7446265 , -0.5555011 , -0.37006748],
#        [ 0.6568905 , -0.51149863, -0.55395305]], dtype=float32), array([0., 0., 0.], dtype=float32), array([[ 0.79322207],
#        [-0.820894  ],
#        [ 1.1347841 ]], dtype=float32), array([0.], dtype=float32)]

# %%
print(model.get_weights()[1].shape)
print(model.get_weights())
# Out:
# (3, 3)
# [array([[-0.5798466 ,  0.2800476 , -0.1869387 ],
#        [-0.52651536,  0.10413212, -0.68871695],
#        [-0.11929303, -0.01671261,  0.6724258 ],
#        [ 0.8392381 ,  0.8242007 , -0.09130085],
#        [-0.19911152,  0.22156435,  0.5324628 ]], dtype=float32), array([[-0.11843264,  0.6555819 , -0.7457789 ],
#        [-0.7446265 , -0.5555011 , -0.37006748],
#        [ 0.6568905 , -0.51149863, -0.55395305]], dtype=float32), array([0., 0., 0.], dtype=float32), array([[ 0.79322207],
#        [-0.820894  ],
#        [ 1.1347841 ]], dtype=float32), array([0.], dtype=float32)]

# %%
print(model.get_weights()[2].shape)
print(model.get_weights())
# Out:
# (3,)
# [array([[-0.5798466 ,  0.2800476 , -0.1869387 ],
#        [-0.52651536,  0.10413212, -0.68871695],
#        [-0.11929303, -0.01671261,  0.6724258 ],
#        [ 0.8392381 ,  0.8242007 , -0.09130085],
#        [-0.19911152,  0.22156435,  0.5324628 ]], dtype=float32), array([[-0.11843264,  0.6555819 , -0.7457789 ],
#        [-0.7446265 , -0.5555011 , -0.37006748],
#        [ 0.6568905 , -0.51149863, -0.55395305]], dtype=float32), array([0., 0., 0.], dtype=float32), array([[ 0.79322207],
#        [-0.820894  ],
#        [ 1.1347841 ]], dtype=float32), array([0.], dtype=float32)]

# %%
print(model.get_weights()[3].shape)
print(model.get_weights())
# Out:
# (3, 1)
# [array([[-0.5798466 ,  0.2800476 , -0.1869387 ],
#        [-0.52651536,  0.10413212, -0.68871695],
#        [-0.11929303, -0.01671261,  0.6724258 ],
#        [ 0.8392381 ,  0.8242007 , -0.09130085],
#        [-0.19911152,  0.22156435,  0.5324628 ]], dtype=float32), array([[-0.11843264,  0.6555819 , -0.7457789 ],
#        [-0.7446265 , -0.5555011 , -0.37006748],
#        [ 0.6568905 , -0.51149863, -0.55395305]], dtype=float32), array([0., 0., 0.], dtype=float32), array([[ 0.79322207],
#        [-0.820894  ],
#        [ 1.1347841 ]], dtype=float32), array([0.], dtype=float32)]

# %%
print(model.get_weights()[4].shape)
print(model.get_weights())
# Out:
# (1,)
# [array([[-0.5798466 ,  0.2800476 , -0.1869387 ],
#        [-0.52651536,  0.10413212, -0.68871695],
#        [-0.11929303, -0.01671261,  0.6724258 ],
#        [ 0.8392381 ,  0.8242007 , -0.09130085],
#        [-0.19911152,  0.22156435,  0.5324628 ]], dtype=float32), array([[-0.11843264,  0.6555819 , -0.7457789 ],
#        [-0.7446265 , -0.5555011 , -0.37006748],
#        [ 0.6568905 , -0.51149863, -0.55395305]], dtype=float32), array([0., 0., 0.], dtype=float32), array([[ 0.79322207],
#        [-0.820894  ],
#        [ 1.1347841 ]], dtype=float32), array([0.], dtype=float32)]
